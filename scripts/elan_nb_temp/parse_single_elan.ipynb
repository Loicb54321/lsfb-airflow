# %%
from lsfb_processing.elan.parser import ElanParser

parser = ElanParser(old_format=False)
parser.parse_eaf("/run/media/ppoitier/ppoitier/datasets/sign-languages/lsfb/cont/targets/ELAN_VALID/CLSFBI01/CLSFBI0104.eaf")
parser.get_errors(), len(parser.videos)
# Out:
# ([], 2)

# %%
parser.get_videos()[0]
# Out:
# Video(eaf_path="CLSFBI0104.eaf", video_path="CLSFBI0104A_S001_B.mp4")

# %%
parser.get_videos()[0].annotations
# Out:
# {'left': [(1851, 2332, 'RENDEZ-VOUS'),
#   (2749, 3298, 'RUE'),
#   (3792, 3967, 'COMMENT'),
#   (4092, 4253, 'APPARAITRE'),
#   (4387, 5200, 'AVANCER'),
#   (5273, 6217, 'PALM-UP'),
#   (48420, 48730, 'BIEN.PAPIER'),
#   (51517, 52300, 'NORMAL.NERVEUX'),
#   (52373, 52659, 'CHANGER.DEVENIR'),
#   (53166, 53555, 'EVOLUTION'),
#   (54237, 54611, 'DIFFERENT'),
#   (54976, 55327, 'POSSIBLE'),
#   (55441, 55928, 'PALM-UP'),
#   (56087, 57275, 'AUSSI'),
#   (57614, 57821, 'HABITER'),
#   (57873, 58178, 'MAISON'),
#   (59071, 59750, 'RENCONTRER'),
#   (60141, 60514, 'PT:PRO1'),
#   (60578, 61693, 'PALM-UP'),
#   (61890, 62095, 'AUSSI'),
#   (62199, 62451, 'AVANCER'),
#   (62515, 63206, 'AUSSI'),
#   (63297, 63711, 'PT:PRO4'),
#   (63730, 64402, 'AUSSI'),
#   (66013, 66360, 'DIFFERENT'),
#   (67814, 68208, 'DIFFERENT'),
#   (69589, 69900, 'PLUSIEURS'),
#   (73703, 73985, 'AUSSI'),
#   (75889, 76795, 'AUSSI'),
#   (79465, 82385, 'PT:LOC'),
#   (82545, 83537, 'PALM-UP'),
# ...
